# %%
from netCDF4 import Dataset

# %%
f = Dataset("test.nc", "r")

# %%
print(f.variables['sst'].shape)
# Out:
# (4320, 8640)

# %%
print(len(f.variables['lat']))
# Out:
# 4320

# %%
print(len(f.variables['lon']))
# Out:
# 8640

# %%
print(f.variables['sst'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 sst(lat, lon)
#     long_name: Sea Surface Temperature
#     scale_factor: 0.005
#     add_offset: 0.0
#     units: degree_C
#     standard_name: sea_surface_temperature
#     _FillValue: -32767
#     valid_min: -1000
#     valid_max: 10000
#     display_scale: linear
#     display_min: -2.0
#     display_max: 45.0
# unlimited dimensions:
# current shape = (4320, 8640)
# filling on

# %%
print(f.variables['qual_sst'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# uint8 qual_sst(lat, lon)
#     long_name: Quality Levels, Sea Surface Temperature
#     _FillValue: 255
#     valid_min: 0
#     valid_max: 5
# unlimited dimensions:
# current shape = (4320, 8640)
# filling on

# %%
for i in f.variables:
    print(i)
# Out:
# sst
# qual_sst
# lat
# lon
# palette

# %%
print(f.variables['lon'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 lon(lon)
#     long_name: Longitude
#     units: degrees_east
#     standard_name: longitude
#     _FillValue: -999.0
#     valid_min: -180.0
#     valid_max: 180.0
# unlimited dimensions:
# current shape = (8640,)
# filling on

# %%
for i in range(len(f.variables['lat'])):
    print(f.variables['lat'][i])
# Out:
# 89.979164
# 89.9375
# 89.89583
# 89.854164
# 89.8125
# 89.77083
# 89.729164
# 89.6875
# 89.64583
# 89.604164
# 89.5625
# 89.52083
# 89.479164
# 89.4375
# 89.39583
# 89.354164
# 89.3125
# 89.27083
# 89.229164
# 89.1875
# 89.14583
# 89.104164
# 89.0625
# 89.02083
# 88.979164
# 88.9375
# 88.89583
# 88.854164
# 88.8125
# 88.77083
# 88.729164
# 88.6875
# 88.64583
# 88.604164
# 88.5625
# 88.52083
# 88.479164
# 88.4375
# 88.39583
# 88.354164
# 88.3125
# 88.27083
# 88.229164
# 88.1875
# 88.14583
# 88.104164
# 88.0625
# 88.02083
# 87.979164
# 87.9375
# 87.89583
# 87.854164
# 87.8125
# 87.77083
# 87.729164
# 87.6875
# 87.64583
# 87.604164
# 87.5625
# 87.52083
# 87.479164
# 87.4375
# 87.39583
# 87.354164
# 87.3125
# 87.27083
# 87.229164
# 87.1875
# 87.14583
# 87.104164
# 87.0625
# 87.02083
# 86.979164
# 86.9375
# 86.89583
# 86.854164
# 86.8125
# 86.77083
# 86.729164
# 86.6875
# 86.64583
# 86.604164
# 86.5625
# 86.52083
# 86.479164
# 86.4375
# 86.39583
# 86.354164
# 86.3125
# 86.27083
# ...

# %%
for i in range(len(f.variables['sst'][0])):
    print(f.variables['sst'][0][i])
# Out:
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# ...

# %%
for i in range(len(f.variables['sst'][1])):
    print(f.variables['sst'][1][i])
# Out:
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# ...

# %%
print(f.variables['sst'][2000][1000])
# Out:
# 28.21

# %%
import pandas as pd

# %%
import numpy as np

# %%
print(np.matrix(f.variables['sst']))
# Out:
# [[-32767. -32767. -32767. ... -32767. -32767. -32767.]
#  [-32767. -32767. -32767. ... -32767. -32767. -32767.]
#  [-32767. -32767. -32767. ... -32767. -32767. -32767.]
#  ...
#  [-32767. -32767. -32767. ... -32767. -32767. -32767.]
#  [-32767. -32767. -32767. ... -32767. -32767. -32767.]
#  [-32767. -32767. -32767. ... -32767. -32767. -32767.]]

# %%
print(f.variables['sst'][:])
# Out:
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]

# %%
df = pd.DataFrame(f.variables['lat'][:])
print(df)
# Out:
#               0
# 0     89.979164
# 1     89.937500
# 2     89.895828
# 3     89.854164
# 4     89.812500
# 5     89.770828
# 6     89.729164
# 7     89.687500
# 8     89.645828
# 9     89.604164
# 10    89.562500
# 11    89.520828
# 12    89.479164
# 13    89.437500
# 14    89.395828
# 15    89.354164
# 16    89.312500
# 17    89.270828
# 18    89.229164
# 19    89.187500
# 20    89.145828
# 21    89.104164
# 22    89.062500
# 23    89.020828
# 24    88.979164
# 25    88.937500
# 26    88.895828
# 27    88.854164
# 28    88.812500
# 29    88.770828
# ...         ...
# 4290 -88.770836
# 4291 -88.812508
# 4292 -88.854179
# 4293 -88.895836
# 4294 -88.937508
# 4295 -88.979179
# 4296 -89.020836
# 4297 -89.062508
# 4298 -89.104179
# 4299 -89.145836
# 4300 -89.187508
# 4301 -89.229179
# 4302 -89.270836
# 4303 -89.312508
# 4304 -89.354179
# 4305 -89.395836
# 4306 -89.437508
# 4307 -89.479179
# 4308 -89.520836
# 4309 -89.562508
# 4310 -89.604179
# 4311 -89.645836
# 4312 -89.687508
# ...

# %%
print(f.variables['lat'][:])
# Out:
# [ 89.979164  89.9375    89.89583  ... -89.895836 -89.93751  -89.97918 ]

# %%
print(f.variables.keys())
# Out:
# odict_keys(['sst', 'qual_sst', 'lat', 'lon', 'palette'])

# %%
df_lon = pd.DataFrame(f.variables['lon'][:10])
print(df_lon)
# Out:
#             0
# 0 -179.979172
# 1 -179.937500
# 2 -179.895844
# 3 -179.854172
# 4 -179.812500
# 5 -179.770844
# 6 -179.729172
# 7 -179.687500
# 8 -179.645844
# 9 -179.604172

# %%
data = {'lat':f.variables['lat'][0:4000],'lon':f.variables['lon'][0:4000]}
df_conc = pd.DataFrame(data)
print(df_conc.shape)
# Out:
# (4000, 2)

# %%
df_conc = pd.DataFrame()

for i in range(len(f.variables['lat'])):
    for x in range(len(f.variables['lon'])):
        data = {'lat':f.variables['lat'][i],'lon':f.variables['lon'][x]}
        df_conc.append(data, ignore_index=True)
                   
print(df_conc.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-b55744cebf4f> in <module>
#       3 for i in range(len(f.variables['lat'])):
#       4     for x in range(len(f.variables['lon'])):
# ----> 5         data = {'lat':f.variables['lat'][i],'lon':f.variables['lon'][x]}
#       6         df_conc.append(data, ignore_index=True)
#       7
#
# netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# c:\users\ih72ca\appdata\local\programs\python\python36\lib\site-packages\netCDF4\utils.py in _StartCountStride(elem, shape, dimensions, grp, datashape, put, use_get_vars)
#      87         return datout
#      88
# ---> 89 def _StartCountStride(elem, shape, dimensions=None, grp=None, datashape=None,\
#      90         put=False, use_get_vars = False):
#      91     """Return start, count, stride and indices needed to store/extract data
#
# KeyboardInterrupt:

# %%
df_conc = pd.DataFrame()

for i in range(0,10):
    for x in range(100,110):
        data = {'lat':f.variables['lat'][i],'lon':f.variables['lon'][x]}     
        df_conc = df_conc.append(data, ignore_index=True)
        
                   
print(df_conc, df_conc.shape)
# Out:
#           lat         lon
# 0   89.979164   -175.8125
# 1   89.979164  -175.77084
# 2   89.979164  -175.72917
# 3   89.979164   -175.6875
# 4   89.979164  -175.64584
# 5   89.979164  -175.60417
# 6   89.979164   -175.5625
# 7   89.979164  -175.52084
# 8   89.979164  -175.47917
# 9   89.979164   -175.4375
# 10    89.9375   -175.8125
# 11    89.9375  -175.77084
# 12    89.9375  -175.72917
# 13    89.9375   -175.6875
# 14    89.9375  -175.64584
# 15    89.9375  -175.60417
# 16    89.9375   -175.5625
# 17    89.9375  -175.52084
# 18    89.9375  -175.47917
# 19    89.9375   -175.4375
# 20   89.89583   -175.8125
# 21   89.89583  -175.77084
# 22   89.89583  -175.72917
# 23   89.89583   -175.6875
# 24   89.89583  -175.64584
# 25   89.89583  -175.60417
# 26   89.89583   -175.5625
# 27   89.89583  -175.52084
# 28   89.89583  -175.47917
# 29   89.89583   -175.4375
# ..        ...         ...
# 70    89.6875   -175.8125
# 71    89.6875  -175.77084
# 72    89.6875  -175.72917
# ...

# %%
df_conc = pd.DataFrame()

for i in range(len(f.variables['lat'])):
    for x in range(len(f.variables['lon'])):
        if f.variables['lat'][i] > 
        data = {'lat':f.variables['lat'][i],'lon':f.variables['lon'][x], 'sst':f.variables['sst'][i][x]}     
        df_conc = df_conc.append(data, ignore_index=True)
        
                   
print(df_conc, df_conc.shape)
# Out:
# Empty DataFrame
# Columns: [lat, lon, sst]
# Index: []

# %%
# df_conc

df_split = df_conc.loc[(df_conc.lat > 89.6875)&(df_conc.lat < 89.89583)]
df_split
# Out:
#           lat         lon sst
# 20   89.89583  -179.97917  --
# 21   89.89583   -179.9375  --
# 22   89.89583  -179.89584  --
# 23   89.89583  -179.85417  --
# 24   89.89583   -179.8125  --
# 25   89.89583  -179.77084  --
# 26   89.89583  -179.72917  --
# 27   89.89583   -179.6875  --
# 28   89.89583  -179.64584  --
# 29   89.89583  -179.60417  --
# 30  89.854164  -179.97917  --
# 31  89.854164   -179.9375  --
# 32  89.854164  -179.89584  --
# 33  89.854164  -179.85417  --
# 34  89.854164   -179.8125  --
# 35  89.854164  -179.77084  --
# 36  89.854164  -179.72917  --
# 37  89.854164   -179.6875  --
# 38  89.854164  -179.64584  --
# 39  89.854164  -179.60417  --
# 40    89.8125  -179.97917  --
# 41    89.8125   -179.9375  --
# 42    89.8125  -179.89584  --
# 43    89.8125  -179.85417  --
# 44    89.8125   -179.8125  --
# 45    89.8125  -179.77084  --
# 46    89.8125  -179.72917  --
# 47    89.8125   -179.6875  --
# 48    89.8125  -179.64584  --
# 49    89.8125  -179.60417  --
# ...

# %%
df_conc = pd.DataFrame()

for i in range(2160,2200):
    for x in range(6480,6500):
        data = {'lat':f.variables['lat'][i],'lon':f.variables['lon'][x],'sst':f.variables['sst'][i][x]}     
        df_conc = df_conc.append(data, ignore_index=True)
        
#df_split = df_conc.loc[(df_conc.lat > 89.6875)&(df_conc.lat < 89.89583)&(df_conc.lon > -20)&(df_conc.lon < 20)]

#print(df_split)
df_conc
# Out:
#               lat        lon        sst
# 0    -0.020833334  90.020836  28.445000
# 1    -0.020833334   90.06252  28.660000
# 2    -0.020833334   90.10418  29.109999
# 3    -0.020833334  90.145836  29.059999
# 4    -0.020833334   90.18752  29.029999
# 5    -0.020833334   90.22918  28.930000
# 6    -0.020833334  90.270836  29.170000
# 7    -0.020833334   90.31252  29.365000
# 8    -0.020833334   90.35418  29.349998
# 9    -0.020833334  90.395836  29.150000
# 10   -0.020833334   90.43752  29.084999
# 11   -0.020833334   90.47918  29.285000
# 12   -0.020833334  90.520836  29.275000
# 13   -0.020833334   90.56252  29.684999
# 14   -0.020833334   90.60418  29.189999
# 15   -0.020833334  90.645836  29.209999
# 16   -0.020833334   90.68752  29.209999
# 17   -0.020833334   90.72918  29.279999
# 18   -0.020833334  90.770836  29.295000
# 19   -0.020833334   90.81252  29.264999
# 20    -0.06250509  90.020836  28.990000
# 21    -0.06250509   90.06252  28.959999
# ...

# %%
df = pd.DataFrame(f.variables['lon'][:])
print(df)
# Out:
#                0
# 0    -179.979172
# 1    -179.937500
# 2    -179.895844
# 3    -179.854172
# 4    -179.812500
# 5    -179.770844
# 6    -179.729172
# 7    -179.687500
# 8    -179.645844
# 9    -179.604172
# 10   -179.562500
# 11   -179.520844
# 12   -179.479172
# 13   -179.437500
# 14   -179.395844
# 15   -179.354172
# 16   -179.312500
# 17   -179.270844
# 18   -179.229172
# 19   -179.187500
# 20   -179.145844
# 21   -179.104172
# 22   -179.062500
# 23   -179.020844
# 24   -178.979172
# 25   -178.937500
# 26   -178.895844
# 27   -178.854172
# 28   -178.812500
# 29   -178.770844
# ...          ...
# 8610  178.770828
# 8611  178.812515
# 8612  178.854172
# 8613  178.895828
# 8614  178.937515
# 8615  178.979172
# 8616  179.020828
# 8617  179.062515
# 8618  179.104172
# 8619  179.145828
# 8620  179.187515
# 8621  179.229172
# 8622  179.270828
# 8623  179.312515
# 8624  179.354172
# 8625  179.395828
# 8626  179.437515
# 8627  179.479172
# 8628  179.520828
# 8629  179.562515
# ...

# %%
df_conc.shape
# Out:
# (40800, 3)

# %%
#air = f.variables['air'][:]
#time = f.variables['time']
lon = f.variables['lon'][:]
lat = f.variables['lat'][:]
print("1")
print(lon,lat)
lon, lat = np.meshgrid(lon, lat)
print("2")
print(lon,lat)
# Out:
# 1
# [-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917] [ 89.979164  89.9375    89.89583  ... -89.895836 -89.93751  -89.97918 ]
# 2
# [[-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917]
#  [-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917]
#  [-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917]
#  ...
#  [-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917]
#  [-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917]
#  [-179.97917 -179.9375  -179.89584 ...  179.89583  179.93752  179.97917]] [[ 89.979164  89.979164  89.979164 ...  89.979164  89.979164  89.979164]
#  [ 89.9375    89.9375    89.9375   ...  89.9375    89.9375    89.9375  ]
#  [ 89.89583   89.89583   89.89583  ...  89.89583   89.89583   89.89583 ]
#  ...
#  [-89.895836 -89.895836 -89.895836 ... -89.895836 -89.895836 -89.895836]
#  [-89.93751  -89.93751  -89.93751  ... -89.93751  -89.93751  -89.93751 ]
# ...

# %%
sst = f.variables['sst'][:]
sst.shape

def plt_map(data):
    m = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80,\
            llcrnrlon=0,urcrnrlon=360,lat_ts=20,resolution='c')
    x, y = m(lon, lat)
    plt.figure(figsize=(10,7))
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
    m.contourf(x,y,data,levels=np.linspace(-25,30,56), extend="both");
    plt.colorbar( orientation='horizontal', pad=0.05)
    
plt_map(sst[0,:,:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-15f2e502ba16> in <module>
#      14     plt.colorbar( orientation='horizontal', pad=0.05)
#      15
# ---> 16 plt_map(sst[0,:,:])
#
# c:\users\ih72ca\appdata\local\programs\python\python36\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3172         # mask of being reshaped if it hasn't been set up properly yet
#    3173         # So it's easier to stick to the current version
# -> 3174         dout = self.data[indx]
#    3175         _mask = self._mask
#    3176
#
# IndexError: too many indices for array

# %%
sst = f.variables['sst'][:]
sst.shape
# Out:
# (4320, 8640)

# %%
lat = f.variables['lat'][:]
lat.shape
# Out:
# (4320,)

# %%
lat.shape
# Out:
# (4320,)

# %%
df_conc.plot(x ='lat', y='sst', kind = 'line')

# %%
df_conc.sst.describe()
# Out:
# count    800.000000
# mean      29.369674
# std        0.256874
# min       28.244999
# 25%       29.224998
# 50%       29.385000
# 75%       29.535000
# max       30.080000
# Name: sst, dtype: float64

# %%
df_conc.plot(kind='scatter',x='ind',y='sst',color='blue')

# %%
ind = range(0,len(df_conc['sst']))
df_conc.insert(0, "ind", ind, True)
df_conc
# Out:
#      ind           lat        lon        sst
# 0      0  -0.020833334  90.020836  28.445000
# 1      1  -0.020833334   90.06252  28.660000
# 2      2  -0.020833334   90.10418  29.109999
# 3      3  -0.020833334  90.145836  29.059999
# 4      4  -0.020833334   90.18752  29.029999
# 5      5  -0.020833334   90.22918  28.930000
# 6      6  -0.020833334  90.270836  29.170000
# 7      7  -0.020833334   90.31252  29.365000
# 8      8  -0.020833334   90.35418  29.349998
# 9      9  -0.020833334  90.395836  29.150000
# 10    10  -0.020833334   90.43752  29.084999
# 11    11  -0.020833334   90.47918  29.285000
# 12    12  -0.020833334  90.520836  29.275000
# 13    13  -0.020833334   90.56252  29.684999
# 14    14  -0.020833334   90.60418  29.189999
# 15    15  -0.020833334  90.645836  29.209999
# 16    16  -0.020833334   90.68752  29.209999
# 17    17  -0.020833334   90.72918  29.279999
# 18    18  -0.020833334  90.770836  29.295000
# 19    19  -0.020833334   90.81252  29.264999
# ...

# %%
# df_conc = df_conc.drop(columns="ind")
df_conc
# Out:
#      ind           lat        lon        sst
# 0      0  -0.020833334  90.020836  28.445000
# 1      1  -0.020833334   90.06252  28.660000
# 2      2  -0.020833334   90.10418  29.109999
# 3      3  -0.020833334  90.145836  29.059999
# 4      4  -0.020833334   90.18752  29.029999
# 5      5  -0.020833334   90.22918  28.930000
# 6      6  -0.020833334  90.270836  29.170000
# 7      7  -0.020833334   90.31252  29.365000
# 8      8  -0.020833334   90.35418  29.349998
# 9      9  -0.020833334  90.395836  29.150000
# 10    10  -0.020833334   90.43752  29.084999
# 11    11  -0.020833334   90.47918  29.285000
# 12    12  -0.020833334  90.520836  29.275000
# 13    13  -0.020833334   90.56252  29.684999
# 14    14  -0.020833334   90.60418  29.189999
# 15    15  -0.020833334  90.645836  29.209999
# 16    16  -0.020833334   90.68752  29.209999
# 17    17  -0.020833334   90.72918  29.279999
# 18    18  -0.020833334  90.770836  29.295000
# 19    19  -0.020833334   90.81252  29.264999
# ...
